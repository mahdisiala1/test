# %%
from typing import TypedDict,List

from langgraph.graph import StateGraph, END
from langchain_groq import ChatGroq
from langgraph.prebuilt import ToolNode

from langchain_core.messages import HumanMessage, AIMessage, BaseMessage,ToolMessage

import json
import ast
from typing import Any

# %%
from __future__ import annotations

from typing import TypedDict, List, Dict, Any, Optional
from dataclasses import dataclass
import math

from langgraph.graph import StateGraph, END

# %%
class ScrumState(TypedDict, total=False):
    cahier_de_charge: str
    team: Dict[str, Any]  # {members:[...], sprint_capacity_points:int, sprint_length_days:int}

    requirements: List[Dict[str, Any]]
    product_backlog: List[Dict[str, Any]]
    refined_backlog: List[Dict[str, Any]]
    estimated_backlog: List[Dict[str, Any]]
    dependencies: List[Dict[str, Any]]

    sprint_backlogs: List[Dict[str, Any]]
    assignments: List[Dict[str, Any]]

    validation: Dict[str, Any]

# %%
import json
from typing import Dict, Any
from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage

llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0
)

def llm_json(prompt: str) -> Dict[str, Any]:
    response = llm.invoke([
        HumanMessage(content=prompt + "\n\nReturn ONLY valid JSON. No markdown.")
    ])

    text = response.content.strip()


    print("text is:"+text)

    # Optional: handle ```json blocks
    if text.find("```json")!=-1:
        start_index = text.find("```json")
        end_index = text.find("```", start_index + 7)
        text = text[start_index + 7:end_index]
        print("new text is:"+text)

    return json.loads(text)

# %%
def extract_requirements_node(state: ScrumState) -> ScrumState:
    spec = state["cahier_de_charge"]

    prompt = f"""
Extract requirements from this cahier de charge.

Return JSON with:
requirements: [
  {{
    "id": "R1",
    "type": "functional|nfr",
    "text": "...",
    "priority": "must|should|could",
    "notes": "optional"
  }}
]

SPEC:
{spec}
"""
    out = llm_json(prompt)
    #print("requirement out is:"+str(out))
    state["requirements"] = out["requirements"]
    return state


def generate_product_backlog_node(state: ScrumState) -> ScrumState:
    reqs = state["requirements"]

    prompt = f"""
Convert requirements into a Scrum Product Backlog.
please for all the field use " " as separator and don't use ' '

Return JSON with:
product_backlog: [
  {{
    "epic": "Epic name",
    "stories": [
      {{
        "id": "US1",
        "title": "...",
        "as_a": "...",
        "i_want": "...",
        "so_that": "...",
        "acceptance_criteria": ["..."],
        "required_skills": ["backend","frontend","devops","qa"]
      }}
    ]
  }}
]

REQUIREMENTS:
{reqs}
"""
    out = llm_json(prompt)

    #print("productBacklog out is:"+str(out))
    state["product_backlog"] = out["product_backlog"]
    return state


def refine_backlog_node(state: ScrumState) -> ScrumState:
    pb = state["product_backlog"]

    prompt = f"""
Refine the backlog using INVEST:
- split stories that are too big
- remove duplicates
- add missing acceptance criteria
Return JSON with:
refined_backlog: [
  {{
    "id": "US1",
    "title": "...",
    "description": "...",
    "acceptance_criteria": ["..."],
    "required_skills": ["backend","frontend","devops","qa"]
  }}
]


IMPORTANT:
- Output ONLY JSON.
- No python code.
- No markdown.
- No explanations.
PRODUCT_BACKLOG:
{pb}
"""
    out = llm_json(prompt)
    print("refined_backlog out is:"+str(out))
    state["refined_backlog"] = out["refined_backlog"]
    return state


def estimate_backlog_node(state: ScrumState) -> ScrumState:
    refined = state["product_backlog"]
    team = state["team"]

    prompt = f"""
Estimate each story using Fibonacci story points: 1,2,3,5,8,13,21.

Return JSON with:
{{
  "estimated_backlog": [
    {{
      "id": "...",
      "title": "...",
      "points": 1|2|3|5|8|13|21,
      "risk": "low|medium|high",
      "complexity": "low|medium|high",
      "required_skills": [...]
    }}
  ]
}}

IMPORTANT:
- Output ONLY JSON.
- No python code.
- No markdown.
- No explanations.

TEAM:
{team}

STORIES:
{refined}
"""

    out = llm_json(prompt)
    print("estimated_backlog out is:"+str(out))
    state["estimated_backlog"] = out["estimated_backlog"]
    return state


def map_dependencies_node(state: ScrumState) -> ScrumState:
    stories = state["estimated_backlog"]

    prompt = f"""
Detect dependencies between stories.

Return JSON with:
dependencies: [
  {{
    "from": "US1",
    "to": "US5",
    "type": "blocks"
  }}
]
STORIES:
{stories}
"""
    out = llm_json(prompt)
    print("dependencies out is:"+str(out))
    state["dependencies"] = out["dependencies"]
    return state

# %%
def sprint_planner_node(state: ScrumState) -> ScrumState:
    stories = state["estimated_backlog"]
    deps = state.get("dependencies", [])
    capacity = int(state["team"].get("sprint_capacity_points", 20))

    # Simple heuristic: order by dependencies first (very simplified)
    # (In production: topological sort)
    ordered = stories[:]  # assume already prioritized by LLM

    sprints = []
    current = {"sprint": 1, "items": [], "total_points": 0}

    for st in ordered:
        pts = int(st["points"])
        if current["total_points"] + pts > capacity and current["items"]:
            sprints.append(current)
            current = {"sprint": current["sprint"] + 1, "items": [], "total_points": 0}

        current["items"].append(st["id"])
        current["total_points"] += pts

    if current["items"]:
        sprints.append(current)

    state["sprint_backlogs"] = sprints
    return state

# %%
def contributor_assigner_node(state: ScrumState) -> ScrumState:
    team_members = state["team"]["members"]
    stories = {s["id"]: s for s in state["estimated_backlog"]}

    # Very simple skill matching:
    # assign 1 main person who matches most skills
    assignments = []

    for sprint in state["sprint_backlogs"]:
        for story_id in sprint["items"]:
            story = stories[story_id]
            req_skills = set(story.get("required_skills", []))

            best = None
            best_score = -1

            for m in team_members:
                skills = set(m.get("skills", []))
                score = len(req_skills.intersection(skills))
                if score > best_score:
                    best_score = score
                    best = m

            assignments.append({
                "story_id": story_id,
                "title": story.get("title", ""),
                "assigned_to": best["name"] if best else None,
                "reason": f"matched_skills={best_score}"
            })

    state["assignments"] = assignments
    return state


def validation_node(state: ScrumState) -> ScrumState:
    capacity = int(state["team"].get("sprint_capacity_points", 20))
    sprints = state["sprint_backlogs"]
    stories = {s["id"]: s for s in state["estimated_backlog"]}

    issues = []

    for sp in sprints:
        total = sum(int(stories[sid]["points"]) for sid in sp["items"])
        if total > capacity:
            issues.append({
                "type": "over_capacity",
                "sprint": sp["sprint"],
                "total_points": total,
                "capacity": capacity
            })

    # Example: detect too big stories
    for s in state["estimated_backlog"]:
        if int(s["points"]) >= 13:
            issues.append({
                "type": "story_too_big",
                "story_id": s["id"],
                "points": s["points"]
            })

    state["validation"] = {
        "ok": len(issues) == 0,
        "issues": issues
    }
    return state

# %%
def route_after_validation(state: ScrumState) -> str:
    if state["validation"]["ok"]:
        return "done"
    # if stories too big -> refine again
    for issue in state["validation"]["issues"]:
        if issue["type"] == "story_too_big":
            return "refine"
    # if over capacity -> plan again
    return "replan"

# %%
def build_scrum_graph():
    g = StateGraph(ScrumState)

    g.add_node("extract_requirements", extract_requirements_node)
    g.add_node("generate_product_backlog", generate_product_backlog_node)
    g.add_node("refine_backlog", refine_backlog_node)
    g.add_node("estimate_backlog", estimate_backlog_node)
    g.add_node("map_dependencies", map_dependencies_node)
    g.add_node("sprint_planner", sprint_planner_node)
    g.add_node("contributor_assigner", contributor_assigner_node)
    g.add_node("validation", validation_node)

    # Edges
    g.set_entry_point("extract_requirements")
    g.add_edge("extract_requirements", "generate_product_backlog")
    g.add_edge("generate_product_backlog", "estimate_backlog")

    g.add_edge("refine_backlog", "estimate_backlog")
    g.add_edge("estimate_backlog", "map_dependencies")
    g.add_edge("map_dependencies", "sprint_planner")
    g.add_edge("sprint_planner", "contributor_assigner")
    g.add_edge("contributor_assigner", "validation")

    # Conditional routing after validation
    g.add_conditional_edges(
        "validation",
        route_after_validation,
        {
            "done": END,
            "refine": "estimate_backlog",
            "replan": "sprint_planner"
        }
    )

    return g.compile()

# %%
if __name__ == "__main__":
    graph = build_scrum_graph()

    cahier_de_charge = """
📄 Cahier de charge — Mini App “Event”
Objectif

Créer une application web pour gérer des événements et les inscriptions.

Acteurs

Membre

Admin

Fonctionnalités

L’admin peut créer un événement (titre, date, capacité).

L’admin peut publier / supprimer un événement.

Le membre peut voir les événements publiés.

Le membre peut s’inscrire à un événement.

Le membre peut annuler son inscription.

Un membre ne peut pas s’inscrire si l’événement est complet.

Contraintes

Authentification par email + mot de passe

Backend: Spring Boot

DB: PostgreSQL
    """

    team = {
        "sprint_length_days": 14,
        "sprint_capacity_points": 20,
        "members": [
            {"name": "Sami", "role": "Backend", "skills": ["backend", "sql", "spring"]},
            {"name": "Ali", "role": "Frontend", "skills": ["frontend", "angular", "ui"]},
            {"name": "Mouna", "role": "DevOps", "skills": ["devops", "docker", "ci_cd"]},
            {"name": "Hela", "role": "QA", "skills": ["qa", "testing"]}
        ]
    }

    result = graph.invoke({
        "cahier_de_charge": cahier_de_charge,
        "team": team
    })

    print("Sprints:", result["sprint_backlogs"])
    print("Assignments:", result["assignments"])
    print("Validation:", result["validation"])
# Out:
# text is:Here are the requirements extracted from the cahier de charge in valid JSON format:
#
# ```json
# {
#   "requirements": [
#     {
#       "id": "R1",
#       "type": "functional",
#       "text": "L'admin peut créer un événement (titre, date, capacité).",
#       "priority": "must"
#     },
#     {
#       "id": "R2",
#       "type": "functional",
#       "text": "L'admin peut publier / supprimer un événement.",
#       "priority": "must"
#     },
#     {
#       "id": "R3",
#       "type": "functional",
#       "text": "Le membre peut voir les événements publiés.",
#       "priority": "must"
#     },
#     {
#       "id": "R4",
#       "type": "functional",
#       "text": "Le membre peut s'inscrire à un événement.",
#       "priority": "must"
#     },
#     {
#       "id": "R5",
#       "type": "functional",
#       "text": "Le membre peut annuler son inscription.",
#       "priority": "must"
#     },
#     {
#       "id": "R6",
#       "type": "nfr",
#       "text": "Un membre ne peut pas s'inscrire si l'événement est complet.",
#       "priority": "must"
#     },
#     {
#       "id": "R7",
#       "type": "nfr",
#       "text": "Authentification par email + mot de passe.",
#       "priority": "must"
#     },
#     {
#       "id": "R8",
#       "type": "nfr",
#       "text": "Backend: Spring Boot.",
#       "priority": "must"
#     },
#     {
#       "id": "R9",
#       "type": "nfr",
#       "text": "DB: PostgreSQL.",
#       "priority": "must"
#     }
#   ]
# }
# ```
# new text is:
# {
#   "requirements": [
#     {
#       "id": "R1",
#       "type": "functional",
#       "text": "L'admin peut créer un événement (titre, date, capacité).",
#       "priority": "must"
#     },
#     {
#       "id": "R2",
#       "type": "functional",
#       "text": "L'admin peut publier / supprimer un événement.",
#       "priority": "must"
#     },
#     {
#       "id": "R3",
#       "type": "functional",
#       "text": "Le membre peut voir les événements publiés.",
#       "priority": "must"
#     },
#     {
#       "id": "R4",
#       "type": "functional",
#       "text": "Le membre peut s'inscrire à un événement.",
#       "priority": "must"
#     },
#     {
#       "id": "R5",
#       "type": "functional",
#       "text": "Le membre peut annuler son inscription.",
#       "priority": "must"
#     },
#     {
#       "id": "R6",
#       "type": "nfr",
#       "text": "Un membre ne peut pas s'inscrire si l'événement est complet.",
#       "priority": "must"
#     },
#     {
#       "id": "R7",
#       "type": "nfr",
#       "text": "Authentification par email + mot de passe.",
#       "priority": "must"
#     },
#     {
#       "id": "R8",
#       "type": "nfr",
#       "text": "Backend: Spring Boot.",
#       "priority": "must"
#     },
#     {
#       "id": "R9",
#       "type": "nfr",
#       "text": "DB: PostgreSQL.",
#       "priority": "must"
#     }
#   ]
# }
#
# text is:```json
# {
#   "product_backlog": [
#     {
#       "epic": "Espace Admin",
#       "stories": [
#         {
#           "id": "US1",
#           "title": "Création d'un événement",
#           "as_a": "L'admin",
#           "i_want": "créer un événement",
#           "so_that": "je puis gérer les événements",
#           "acceptance_criteria": [
#             "L'événement est créé avec un titre",
#             "L'événement est créé avec une date",
#             "L'événement est créé avec une capacité"
#           ],
#           "required_skills": ["backend","frontend","devops","qa"]
#         },
#         {
#           "id": "US2",
#           "title": "Gestion des événements",
#           "as_a": "L'admin",
#           "i_want": "publier ou supprimer un événement",
#           "so_that": "je puis gérer les événements",
#           "acceptance_criteria": [
#             "L'événement est publié avec succès",
#             "L'événement est supprimé avec succès"
#           ],
#           "required_skills": ["backend","frontend","devops","qa"]
#         },
#         {
#           "id": "US3",
#           "title": "Affichage des événements",
#           "as_a": "Le membre",
#           "i_want": "voir les événements publiés",
#           "so_that": "je puis voir les événements",
#           "acceptance_criteria": [
#             "Les événements sont affichés avec succès"
#           ],
#           "required_skills": ["frontend"]
#         },
#         {
#           "id": "US4",
#           "title": "Inscription à un événement",
#           "as_a": "Le membre",
#           "i_want": "s'inscrire à un événement",
#           "so_that": "je puis participer aux événements",
#           "acceptance_criteria": [
#             "L'inscription est effectuée avec succès"
#           ],
#           "required_skills": ["backend","frontend","devops","qa"]
#         },
#         {
#           "id": "US5",
#           "title": "Annulation d'une inscription",
#           "as_a": "Le membre",
#           "i_want": "annuler son inscription",
#           "so_that": "je puis annuler mon inscription",
#           "acceptance_criteria": [
#             "L'inscription est annulée avec succès"
#           ],
#           "required_skills": ["backend","frontend","devops","qa"]
#         },
#         {
#           "id": "US6",
#           "title": "Vérification de la capacité d'un événement",
#           "as_a": "Le membre",
#           "i_want": "ne pas s'inscrire si l'événement est complet",
#           "so_that": "je puis éviter les événements complets",
#           "acceptance_criteria": [
#             "L'inscription est refusée si l'événement est complet"
#           ],
#           "required_skills": ["backend","frontend","devops","qa"]
#         },
#         {
#           "id": "US7",
#           "title": "Authentification",
#           "as_a": "Le membre",
#           "i_want": "se connecter avec un email et un mot de passe",
#           "so_that": "je puis accéder à l'espace membre",
#           "acceptance_criteria": [
#             "La connexion est effectuée avec succès"
#           ],
#           "required_skills": ["backend","frontend","devops","qa"]
#         },
#         {
#           "id": "US8",
#           "title": "Backend",
#           "as_a": "Le développeur",
#           "i_want": "utiliser Spring Boot",
#           "so_that": "je puis développer le backend",
#           "acceptance_criteria": [
#             "Le backend est développé avec succès"
#           ],
#           "required_skills": ["backend"]
#         },
#         {
#           "id": "US9",
#           "title": "Base de données",
#           "as_a": "Le développeur",
#           "i_want": "utiliser PostgreSQL",
#           "so_that": "je puis stocker les données",
#           "acceptance_criteria": [
#             "La base de données est configurée avec succès"
#           ],
#           "required_skills": ["backend"]
#         }
#       ]
#     }
#   ]
# }
# ```
# new text is:
# {
#   "product_backlog": [
#     {
#       "epic": "Espace Admin",
#       "stories": [
#         {
#           "id": "US1",
#           "title": "Création d'un événement",
#           "as_a": "L'admin",
#           "i_want": "créer un événement",
#           "so_that": "je puis gérer les événements",
#           "acceptance_criteria": [
#             "L'événement est créé avec un titre",
#             "L'événement est créé avec une date",
#             "L'événement est créé avec une capacité"
#           ],
#           "required_skills": ["backend","frontend","devops","qa"]
#         },
#         {
#           "id": "US2",
#           "title": "Gestion des événements",
#           "as_a": "L'admin",
#           "i_want": "publier ou supprimer un événement",
#           "so_that": "je puis gérer les événements",
#           "acceptance_criteria": [
#             "L'événement est publié avec succès",
#             "L'événement est supprimé avec succès"
#           ],
#           "required_skills": ["backend","frontend","devops","qa"]
#         },
#         {
#           "id": "US3",
#           "title": "Affichage des événements",
#           "as_a": "Le membre",
#           "i_want": "voir les événements publiés",
#           "so_that": "je puis voir les événements",
#           "acceptance_criteria": [
#             "Les événements sont affichés avec succès"
#           ],
#           "required_skills": ["frontend"]
#         },
#         {
#           "id": "US4",
#           "title": "Inscription à un événement",
#           "as_a": "Le membre",
#           "i_want": "s'inscrire à un événement",
#           "so_that": "je puis participer aux événements",
#           "acceptance_criteria": [
#             "L'inscription est effectuée avec succès"
#           ],
#           "required_skills": ["backend","frontend","devops","qa"]
#         },
#         {
#           "id": "US5",
#           "title": "Annulation d'une inscription",
#           "as_a": "Le membre",
#           "i_want": "annuler son inscription",
#           "so_that": "je puis annuler mon inscription",
#           "acceptance_criteria": [
#             "L'inscription est annulée avec succès"
#           ],
#           "required_skills": ["backend","frontend","devops","qa"]
#         },
#         {
#           "id": "US6",
#           "title": "Vérification de la capacité d'un événement",
#           "as_a": "Le membre",
#           "i_want": "ne pas s'inscrire si l'événement est complet",
#           "so_that": "je puis éviter les événements complets",
#           "acceptance_criteria": [
#             "L'inscription est refusée si l'événement est complet"
#           ],
#           "required_skills": ["backend","frontend","devops","qa"]
#         },
#         {
#           "id": "US7",
#           "title": "Authentification",
#           "as_a": "Le membre",
#           "i_want": "se connecter avec un email et un mot de passe",
#           "so_that": "je puis accéder à l'espace membre",
#           "acceptance_criteria": [
#             "La connexion est effectuée avec succès"
#           ],
#           "required_skills": ["backend","frontend","devops","qa"]
#         },
#         {
#           "id": "US8",
#           "title": "Backend",
#           "as_a": "Le développeur",
#           "i_want": "utiliser Spring Boot",
#           "so_that": "je puis développer le backend",
#           "acceptance_criteria": [
#             "Le backend est développé avec succès"
#           ],
#           "required_skills": ["backend"]
#         },
#         {
#           "id": "US9",
#           "title": "Base de données",
#           "as_a": "Le développeur",
#           "i_want": "utiliser PostgreSQL",
#           "so_that": "je puis stocker les données",
#           "acceptance_criteria": [
#             "La base de données est configurée avec succès"
#           ],
#           "required_skills": ["backend"]
#         }
#       ]
#     }
#   ]
# }
#
# text is:{
#   "estimated_backlog": [
#     {
#       "id": "US1",
#       "title": "Cr\u00e9ation d'un \u00e9v\u00e9nement",
#       "points": 8,
#       "risk": "medium",
#       "complexity": "medium",
#       "required_skills": ["backend", "frontend", "devops", "qa"]
#     },
#     {
#       "id": "US2",
#       "title": "Gestion des \u00e9v\u00e9nements",
#       "points": 8,
#       "risk": "medium",
#       "complexity": "medium",
#       "required_skills": ["backend", "frontend", "devops", "qa"]
#     },
#     {
#       "id": "US3",
#       "title": "Affichage des \u00e9v\u00e9nements",
#       "points": 3,
#       "risk": "low",
#       "complexity": "low",
#       "required_skills": ["frontend"]
#     },
#     {
#       "id": "US4",
#       "title": "Inscription \u00e0 un \u00e9v\u00e9nement",
#       "points": 8,
#       "risk": "medium",
#       "complexity": "medium",
#       "required_skills": ["backend", "frontend", "devops", "qa"]
#     },
#     {
#       "id": "US5",
#       "title": "\u00c9tannulation d\u2019une inscription",
#       "points": 5,
#       "risk": "medium",
#       "complexity": "medium",
#       "required_skills": ["backend", "frontend", "devops", "qa"]
#     },
#     {
#       "id": "US6",
#       "title": "\u00c9tannulation d\u2019une inscription",
#       "points": 5,
#       "risk": "medium",
#       "complexity": "medium",
#       "required_skills": ["backend", "frontend", "devops", "qa"]
#     },
#     {
#       "id": "US7",
#       "title": "Authentification",
#       "points": 8,
#       "risk": "medium",
#       "complexity": "medium",
#       "required_skills": ["backend", "frontend", "devops", "qa"]
#     },
#     {
#       "id": "US8",
#       "title": "Backend",
#       "points": 1,
#       "risk": "low",
#       "complexity": "low",
#       "required_skills": ["backend"]
#     },
#     {
#       "id": "US9",
#       "title": "Base de donn\u00e9es",
#       "points": 1,
#       "risk": "low",
#       "complexity": "low",
#       "required_skills": ["backend"]
#     }
#   ]
# }
# estimated_backlog out is:{'estimated_backlog': [{'id': 'US1', 'title': "Création d'un événement", 'points': 8, 'risk': 'medium', 'complexity': 'medium', 'required_skills': ['backend', 'frontend', 'devops', 'qa']}, {'id': 'US2', 'title': 'Gestion des événements', 'points': 8, 'risk': 'medium', 'complexity': 'medium', 'required_skills': ['backend', 'frontend', 'devops', 'qa']}, {'id': 'US3', 'title': 'Affichage des événements', 'points': 3, 'risk': 'low', 'complexity': 'low', 'required_skills': ['frontend']}, {'id': 'US4', 'title': 'Inscription à un événement', 'points': 8, 'risk': 'medium', 'complexity': 'medium', 'required_skills': ['backend', 'frontend', 'devops', 'qa']}, {'id': 'US5', 'title': 'Étannulation d’une inscription', 'points': 5, 'risk': 'medium', 'complexity': 'medium', 'required_skills': ['backend', 'frontend', 'devops', 'qa']}, {'id': 'US6', 'title': 'Étannulation d’une inscription', 'points': 5, 'risk': 'medium', 'complexity': 'medium', 'required_skills': ['backend', 'frontend', 'devops', 'qa']}, {'id': 'US7', 'title': 'Authentification', 'points': 8, 'risk': 'medium', 'complexity': 'medium', 'required_skills': ['backend', 'frontend', 'devops', 'qa']}, {'id': 'US8', 'title': 'Backend', 'points': 1, 'risk': 'low', 'complexity': 'low', 'required_skills': ['backend']}, {'id': 'US9', 'title': 'Base de données', 'points': 1, 'risk': 'low', 'complexity': 'low', 'required_skills': ['backend']}]}
# text is:```python
# import json
#
# def detect_dependencies(stories):
#     dependencies = []
#     for i in range(len(stories)):
#         for j in range(i + 1, len(stories)):
#             if set(stories[i]['required_skills']) & set(stories[j]['required_skills']):
#                 dependencies.append({
#                     "from": stories[i]['id'],
#                     "to": stories[j]['id'],
#                     "type": "blocks"
#                 })
#     return json.dumps({"dependencies": dependencies})
#
# stories = [
#     {'id': 'US1', 'title': "Création d'un événement", 'points': 8, 'risk': 'medium', 'complexity': 'medium', 'required_skills': ['backend', 'frontend', 'devops', 'qa']},
#     {'id': 'US2', 'title': 'Gestion des événements', 'points': 8, 'risk': 'medium', 'complexity': 'medium', 'required_skills': ['backend', 'frontend', 'devops', 'qa']},
#     {'id': 'US3', 'title': 'Affichage des événements', 'points': 3, 'risk': 'low', 'complexity': 'low', 'required_skills': ['frontend']},
#     {'id': 'US4', 'title': 'Inscription à un événement', 'points': 8, 'risk': 'medium', 'complexity': 'medium', 'required_skills': ['backend', 'frontend', 'devops', 'qa']},
#     {'id': 'US5', 'title': 'Étannulation d’une inscription', 'points': 5, 'risk': 'medium', 'complexity': 'medium', 'required_skills': ['backend', 'frontend', 'devops', 'qa']},
#     {'id': 'US6', 'title': 'Étannulation d’une inscription', 'points': 5, 'risk': 'medium', 'complexity': 'medium', 'required_skills': ['backend', 'frontend', 'devops', 'qa']},
#     {'id': 'US7', 'title': 'Authentification', 'points': 8, 'risk': 'medium', 'complexity': 'medium', 'required_skills': ['backend', 'frontend', 'devops', 'qa']},
#     {'id': 'US8', 'title': 'Backend', 'points': 1, 'risk': 'low', 'complexity': 'low', 'required_skills': ['backend']},
#     {'id': 'US9', 'title': 'Base de données', 'points': 1, 'risk': 'low', 'complexity': 'low', 'required_skills': ['backend']}
# ]
#
# print(detect_dependencies(stories))
# ```
#
# This script will output:
#
# ```json
# {"dependencies": [{"from": "US1", "to": "US2", "type": "blocks"}, {"from": "US1", "to": "US4", "type": "blocks"}, {"from": "US1", "to": "US5", "type": "blocks"}, {"from": "US1", "to": "US6", "type": "blocks"}, {"from": "US1", "to": "US7", "type": "blocks"}, {"from": "US2", "to": "US4", "type": "blocks"}, {"from": "US2", "to": "US5", "type": "blocks"}, {"from": "US2", "to": "US6", "type": "blocks"}, {"from": "US2", "to": "US7", "type": "blocks"}, {"from": "US4", "to": "US5", "type": "blocks"}, {"from": "US4", "to": "US6", "type": "blocks"}, {"from": "US4", "to": "US7", "type": "blocks"}, {"from": "US5", "to": "US6", "type": "blocks"}, {"from": "US5", "to": "US7", "type": "blocks"}, {"from": "US6", "to": "US7", "type": "blocks"}]}
# ```
# new text is:
# {"dependencies": [{"from": "US1", "to": "US2", "type": "blocks"}, {"from": "US1", "to": "US4", "type": "blocks"}, {"from": "US1", "to": "US5", "type": "blocks"}, {"from": "US1", "to": "US6", "type": "blocks"}, {"from": "US1", "to": "US7", "type": "blocks"}, {"from": "US2", "to": "US4", "type": "blocks"}, {"from": "US2", "to": "US5", "type": "blocks"}, {"from": "US2", "to": "US6", "type": "blocks"}, {"from": "US2", "to": "US7", "type": "blocks"}, {"from": "US4", "to": "US5", "type": "blocks"}, {"from": "US4", "to": "US6", "type": "blocks"}, {"from": "US4", "to": "US7", "type": "blocks"}, {"from": "US5", "to": "US6", "type": "blocks"}, {"from": "US5", "to": "US7", "type": "blocks"}, {"from": "US6", "to": "US7", "type": "blocks"}]}
#
# dependencies out is:{'dependencies': [{'from': 'US1', 'to': 'US2', 'type': 'blocks'}, {'from': 'US1', 'to': 'US4', 'type': 'blocks'}, {'from': 'US1', 'to': 'US5', 'type': 'blocks'}, {'from': 'US1', 'to': 'US6', 'type': 'blocks'}, {'from': 'US1', 'to': 'US7', 'type': 'blocks'}, {'from': 'US2', 'to': 'US4', 'type': 'blocks'}, {'from': 'US2', 'to': 'US5', 'type': 'blocks'}, {'from': 'US2', 'to': 'US6', 'type': 'blocks'}, {'from': 'US2', 'to': 'US7', 'type': 'blocks'}, {'from': 'US4', 'to': 'US5', 'type': 'blocks'}, {'from': 'US4', 'to': 'US6', 'type': 'blocks'}, {'from': 'US4', 'to': 'US7', 'type': 'blocks'}, {'from': 'US5', 'to': 'US6', 'type': 'blocks'}, {'from': 'US5', 'to': 'US7', 'type': 'blocks'}, {'from': 'US6', 'to': 'US7', 'type': 'blocks'}]}
# Sprints: [{'sprint': 1, 'items': ['US1', 'US2', 'US3'], 'total_points': 19}, {'sprint': 2, 'items': ['US4', 'US5', 'US6'], 'total_points': 18}, {'sprint': 3, 'items': ['US7', 'US8', 'US9'], 'total_points': 10}]
# Assignments: [{'story_id': 'US1', 'title': "Création d'un événement", 'assigned_to': 'Sami', 'reason': 'matched_skills=1'}, {'story_id': 'US2', 'title': 'Gestion des événements', 'assigned_to': 'Sami', 'reason': 'matched_skills=1'}, {'story_id': 'US3', 'title': 'Affichage des événements', 'assigned_to': 'Ali', 'reason': 'matched_skills=1'}, {'story_id': 'US4', 'title': 'Inscription à un événement', 'assigned_to': 'Sami', 'reason': 'matched_skills=1'}, {'story_id': 'US5', 'title': 'Étannulation d’une inscription', 'assigned_to': 'Sami', 'reason': 'matched_skills=1'}, {'story_id': 'US6', 'title': 'Étannulation d’une inscription', 'assigned_to': 'Sami', 'reason': 'matched_skills=1'}, {'story_id': 'US7', 'title': 'Authentification', 'assigned_to': 'Sami', 'reason': 'matched_skills=1'}, {'story_id': 'US8', 'title': 'Backend', 'assigned_to': 'Sami', 'reason': 'matched_skills=1'}, {'story_id': 'US9', 'title': 'Base de données', 'assigned_to': 'Sami', 'reason': 'matched_skills=1'}]
# Validation: {'ok': True, 'issues': []}
